# %%
pip install spotipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id = '4ddf454f1e8b4c7b985906d962cc5102',
                                                      client_secret='b1769208010d484a9e6c9a198bc34fd3')
#Authentication

# %%
sp=spotipy.Spotify(client_credentials_manager = client_credentials_manager)
#Authorisation

# %%
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF'

# %%
playlist_uri = playlist_link.split('/')[-1]

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data['items']
# Out:
# [{'added_at': '2024-02-16T12:05:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#       'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#       'id': '22wbnEMDvgVIAGdFeek6ET',
#       'name': 'Benson Boone',
#       'type': 'artist',
#       'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
print('\n album id:', data['items'][0]['track']['album']['id'])
print('\n song name:', data['items'][0]['track']['name'])
print('\n album name:', data['items'][0]['track']['album']['name'])
print('\n album release date:', data['items'][0]['track']['album']['release_date'])
print('\n total tracks in album:', data['items'][0]['track']['album']['total_tracks'])
print('\n url:', data['items'][0]['track']['album']['external_urls']['spotify'])
# Out:
#  album id: 29aSKB1qPEbN0Qf9OPSQpw
#
#  song name: Beautiful Things
#
#  album name: Beautiful Things
#
#  album release date: 2024-01-18
#
#  total tracks in album: 1
#
#  url: https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '29aSKB1qPEbN0Qf9OPSQpw',
#   'name': 'Beautiful Things',
#   'release_date': '2024-01-18',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/29aSKB1qPEbN0Qf9OPSQpw'},
#  {'album_id': '2IoSjweCu07y9mv5H1Cj3v',
#   'name': 'La Diabla',
#   'release_date': '2023-11-30',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/2IoSjweCu07y9mv5H1Cj3v'},
#  {'album_id': '3UOV8XvCwMKaATRNXrYCjN',
#   'name': 'greedy',
#   'release_date': '2023-09-15',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/3UOV8XvCwMKaATRNXrYCjN'},
#  {'album_id': '30zwjSQEodaUXCn11nmiVF',
#   'name': 'VULTURES 1',
#   'release_date': '2024-02-09',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/30zwjSQEodaUXCn11nmiVF'},
#  {'album_id': '1NAmidJlEaVgA3MpcPFYGq',
#   'name': 'Lover',
#   'release_date': '2019-08-23',
#   'total_tracks': 18,
#   'url': 'https://open.spotify.com/album/1NAmidJlEaVgA3MpcPFYGq'},
# ...

# %%
import json
json.dumps(data['items'][0])
# Out:
# '{"added_at": "2024-02-16T12:05:52Z", "added_by": {"external_urls": {"spotify": "https://open.spotify.com/user/"}, "href": "https://api.spotify.com/v1/users/", "id": "", "type": "user", "uri": "spotify:user:"}, "is_local": false, "primary_color": null, "track": {"album": {"album_type": "single", "artists": [{"external_urls": {"spotify": "https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET"}, "href": "https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET", "id": "22wbnEMDvgVIAGdFeek6ET", "name": "Benson Boone", "type": "artist", "uri": "spotify:artist:22wbnEMDvgVIAGdFeek6ET"}], "available_markets": ["AR", "AU", "AT", "BE", "BO", "BR", "BG", "CA", "CL", "CO", "CR", "CY", "CZ", "DK", "DO", "DE", "EC", "EE", "SV", "FI", "FR", "GR", "GT", "HN", "HK", "HU", "IS", "IE", "IT", "LV", "LT", "LU", "MY", "MT", "MX", "NL", "NZ", "NI", "NO", "PA", "PY", "PE", "PH", "PL", "PT", "SG", "SK", "ES", "SE", "CH", "TW", "TR", "UY", "US", "GB", "AD", "LI", "MC", "ID", "JP", "TH", "VN", "RO", "IL", "
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 
                               'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list = []
for row in data['items']:
    artist_list.extend(row['track']['artists'])
#     for key, value in row.items():
#         if key == "track":
#             for artist in value['artists']:
#                 artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 
#                                'external_url': artist['href']}
#                 artist_list.append(artist_dict)

artist_list
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22wbnEMDvgVIAGdFeek6ET'},
#   'href': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET',
#   'id': '22wbnEMDvgVIAGdFeek6ET',
#   'name': 'Benson Boone',
#   'type': 'artist',
#   'uri': 'spotify:artist:22wbnEMDvgVIAGdFeek6ET'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3Me35AWHCGqW4sZ7bWWJt1'},
#   'href': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1',
#   'id': '3Me35AWHCGqW4sZ7bWWJt1',
#   'name': 'Xavi',
#   'type': 'artist',
#   'uri': 'spotify:artist:3Me35AWHCGqW4sZ7bWWJt1'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym'},
#   'href': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym',
#   'id': '45dkTj5sMRSjrmBSBeiHym',
#   'name': 'Tate McRae',
#   'type': 'artist',
#   'uri': 'spotify:artist:45dkTj5sMRSjrmBSBeiHym'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4xPQFgDA5M2xa0ZGo5iIsv'},
# ...

# %%
artist_list
# Out:
# [{'artist_id': '22wbnEMDvgVIAGdFeek6ET',
#   'artist_name': 'Benson Boone',
#   'external_url': 'https://api.spotify.com/v1/artists/22wbnEMDvgVIAGdFeek6ET'},
#  {'artist_id': '3Me35AWHCGqW4sZ7bWWJt1',
#   'artist_name': 'Xavi',
#   'external_url': 'https://api.spotify.com/v1/artists/3Me35AWHCGqW4sZ7bWWJt1'},
#  {'artist_id': '45dkTj5sMRSjrmBSBeiHym',
#   'artist_name': 'Tate McRae',
#   'external_url': 'https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym'},
#  {'artist_id': '4xPQFgDA5M2xa0ZGo5iIsv',
#   'artist_name': '¥$',
#   'external_url': 'https://api.spotify.com/v1/artists/4xPQFgDA5M2xa0ZGo5iIsv'},
#  {'artist_id': '5K4W6rqBFWDnAN6FQUkS6x',
#   'artist_name': 'Kanye West',
#   'external_url': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x'},
#  {'artist_id': '7c0XG5cIJTrrAgEC3ULPiq',
#   'artist_name': 'Ty Dolla $ign',
#   'external_url': 'https://api.spotify.com/v1/artists/7c0XG5cIJTrrAgEC3ULPiq'},
#  {'artist_id': '06HL4z0CvFAxyc27GXpf02',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id              name release_date  total_tracks  \
# 0  29aSKB1qPEbN0Qf9OPSQpw  Beautiful Things   2024-01-18             1
# 1  2IoSjweCu07y9mv5H1Cj3v         La Diabla   2023-11-30             1
# 2  3UOV8XvCwMKaATRNXrYCjN            greedy   2023-09-15             1
# 3  30zwjSQEodaUXCn11nmiVF        VULTURES 1   2024-02-09            16
# 4  1NAmidJlEaVgA3MpcPFYGq             Lover   2019-08-23            18
#
#                                                  url
# 0  https://open.spotify.com/album/29aSKB1qPEbN0Qf...
# 1  https://open.spotify.com/album/2IoSjweCu07y9mv...
# 2  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 3  https://open.spotify.com/album/30zwjSQEodaUXCn...
# 4  https://open.spotify.com/album/1NAmidJlEaVgA3M...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id         song_name  duration_ms  \
# 0  6tNQ70jh4OwmPGpYy6R2o9  Beautiful Things       180304
# 1  0R6NfOiLzLj4O5VbYSJAjf         La Diabla       172264
# 2  3rUGC1vUpkDG9CZFHMur1t            greedy       131872
# 3  3w0w2T288dec0mgeZZqoNN          CARNIVAL       264324
# 4  1BxfuPKGuaTgP7aM0Bbdwr      Cruel Summer       178426
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6tNQ70jh4OwmPGp...          97
# 1  https://open.spotify.com/track/0R6NfOiLzLj4O5V...          99
# 2  https://open.spotify.com/track/3rUGC1vUpkDG9CZ...         100
# 3  https://open.spotify.com/track/3w0w2T288dec0mg...          33
# 4  https://open.spotify.com/track/1BxfuPKGuaTgP7a...          99
#
#              song_added                album_id               artist_id
# 0  2024-02-16T12:05:52Z  29aSKB1qPEbN0Qf9OPSQpw  22wbnEMDvgVIAGdFeek6ET
# 1  2024-02-16T12:05:52Z  2IoSjweCu07y9mv5H1Cj3v  3Me35AWHCGqW4sZ7bWWJt1
# ...

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  22wbnEMDvgVIAGdFeek6ET  Benson Boone
# 1  3Me35AWHCGqW4sZ7bWWJt1          Xavi
# 2  45dkTj5sMRSjrmBSBeiHym    Tate McRae
# 3  4xPQFgDA5M2xa0ZGo5iIsv            ¥$
# 4  5K4W6rqBFWDnAN6FQUkS6x    Kanye West
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/22wbnEMDvgV...
# 1  https://api.spotify.com/v1/artists/3Me35AWHCGq...
# 2  https://api.spotify.com/v1/artists/45dkTj5sMRS...
# 3  https://api.spotify.com/v1/artists/4xPQFgDA5M2...
# 4  https://api.spotify.com/v1/artists/5K4W6rqBFWD...

# %%
album_df.head()
# Out:
#                  album_id              name release_date  total_tracks  \
# 0  29aSKB1qPEbN0Qf9OPSQpw  Beautiful Things   2024-01-18             1
# 1  2IoSjweCu07y9mv5H1Cj3v         La Diabla   2023-11-30             1
# 2  3UOV8XvCwMKaATRNXrYCjN            greedy   2023-09-15             1
# 3  30zwjSQEodaUXCn11nmiVF        VULTURES 1   2024-02-09            16
# 4  1NAmidJlEaVgA3MpcPFYGq             Lover   2019-08-23            18
#
#                                                  url
# 0  https://open.spotify.com/album/29aSKB1qPEbN0Qf...
# 1  https://open.spotify.com/album/2IoSjweCu07y9mv...
# 2  https://open.spotify.com/album/3UOV8XvCwMKaATR...
# 3  https://open.spotify.com/album/30zwjSQEodaUXCn...
# 4  https://open.spotify.com/album/1NAmidJlEaVgA3M...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB

# %%
# !python -- version
# Out:
# python: can't open file '/Users/srihari/version': [Errno 2] No such file or directory
